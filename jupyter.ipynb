# %% [markdown]
# <a href="https://colab.research.google.com/github/sanoakr/rumath-network/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jupyter とは
#
# Jupyter（ジュピター）は、Python をインタラクティブに動作させるための対話型の実行環境です。Jupyter では、この文章のようにテキストや数式 $\sin^2\theta + \cos^2\theta = 1$、また、画像データなども含めることができます。
# Jupyter で動作させるために、テキストや Python コードをひとまとまりにしたファイルを Jupyter Notebook（ジュピター・ノートブック）と呼びます。このファイルこのファイル jupyter.ipynb は Jupyter Notebook の一例です。

# %% [markdown]
# Python のコードは以下のようなBOX（コードセルと呼ばれます）に記述され、このセルを選択した状態で Shift+Enter または、セル左横の ▷ マークをクリックすることでセル内の Python コードを実行することができます。

# %% [markdown]
# 以下の2つのセルを上から順に実行してみましょう。

# %%
a = 1234
b = 5678

# %%
b/a
# Out:
# 4.60129659643436

# %% [markdown]
# b/a の計算結果がセルの下に表示されたと思います。
# 次に、a, b の値を変更するなどセル内のコードを書き換えてから、再び2つのセルを実行してみてください。b/a の結果の値が変わっているはずです。
# このように、Jupyter Notebook ではコードセル内の Python コードを対話的に修正、実行することができます。

# %% [markdown]
# Jupyter Notebook のコードセルは、ノートブック内に複数記述することができます。ノートブック内のコードセルは独立しておらず、名前空間を共有しています。
# したがって、以下のセルを実行した後、再び上にある b/a のセルを評価すると、a, b の値は直近に評価された値 $a=0.1, b=123^{99}$として計算されることになります。

# %%
a = 0.1
b = 123**99

# %% [markdown]
# 同じノートブック内のセルでも、セルが評価される順番によって結果が異なることに注意してください。そのセルが何番目に実行されたかは、セルの左横（▷の位置）に表示されます。
